# %% [markdown]
# <a href="https://colab.research.google.com/github/Abinash2k/Hotel-booking-Analysis/blob/main/EDA_Project5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - HOTEL BOOKING ANALYSIS

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Contributor -**  Abinash Mukherjee

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Have you ever wondered when the best time of year to book a hotel room is? Or the optimal length of stay in order to get the best daily rate? What if you wanted to predict whether or not a hotel was likely to receive a disproportionately high number of special requests? This hotel booking dataset can help you explore those questions!
# This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things. All personally identifying information has been removed from the data.
# Explore and analyze the data to discover important factors that govern the bookings.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/Abinash2k/Hotel-booking-Analysis

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things. All personally identifying information has been removed from the data. Explore and analyse the data to discover important factors that govern the bookings.**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Business objective generally depends on the hotel management's or stakeholders' specific goals and needs. In my case following are a few objectives, I found after research.
#
# * Minimize Booking Cancellations: Reduce the rate of booking cancellations by identifying factors that contribute to cancellations and implementing strategies to mitigate them.
#
# * Maximize Revenue: Optimize pricing strategies to maximize revenue, such as adjusting room rates based on demand and seasonality.
#
# * Enhance Customer Satisfaction: Improve the overall guest experience by identifying areas where improvements can be made, such as service quality, room preferences, and special requests.
#
# * Forecast Demand: Accurately predict future booking demand to optimize resource allocation, including staffing levels, room availability, and inventory management.
#
# * Identify Customer Segments: Segment customers based on their booking behavior, preferences, and demographics to tailor marketing and service offerings to different groups.
#
# * Improve Marketing Strategies: Evaluate the effectiveness of marketing channels and campaigns in attracting bookings and allocate marketing budgets more efficiently.
#
# * Reduce Operational Costs: Identify opportunities to reduce operational costs, such as optimizing staffing schedules and reducing overbooking.
#
# * Ensure Regulatory Compliance: Ensure that the hotel is compliant with relevant regulations and standards, such as data privacy regulations (e.g., GDPR) and safety protocols.
#
# * Monitor Competitor Performance: Analyze how the hotel's booking metrics compare to competitors in the same market and identify areas for improvement.
#
# * Enhance Long-Term Planning: Use historical booking data to inform long-term strategic planning, including property expansions and renovations.
#
# It's essential to define a clear and specific business objective before conducting a hotel booking analysis to ensure that the analysis provides actionable insights and helps the hotel achieve its goals.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
# First thing we need to import all our usefull libraries.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
files = ('/content/drive/MyDrive/Data Sets/Hotel Bookings.csv')
data = pd.read_csv(files)
data.head()  #This is how our data looks like.
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
rows = len(data.axes[0])
columns = len(data.axes[1])
# This code count all the rows and columns we have in our dataset.
print(f'Total rows are {rows} and total columns are {columns} in this dataset')
# Out:
# Total rows are 119390 and total columns are 32 in this dataset

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
total_duplicates = data[data.duplicated()].shape[0]
print("Total duplicates:", total_duplicates) #This shows all the dublicate value we have in our dataset
# Out:
# Total duplicates: 31994

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
data.isnull().sum() #by this we will get to know all the null values we have in our dataset in particular columns
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
# Visualizing the missing values
missing_value = data.isnull().sum()

plt.figure(figsize=(10, 8))   #this code set the size of visual image
sns.barplot(x=missing_value.values, y=missing_value.index)
plt.xlabel('Missing Values')
plt.ylabel('Heading')
plt.title('Missing Values by Column')
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Till now I came to know that my dataset has 119390 columns and 32 rows, not only that it has 31994 dublicate values and 129425 null values.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
data.columns  #all the columns we have in our dataset
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Dataset Describe
data.describe()   #This describe basic calculation in the dataset such as count,mean,std,min,max etc.
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# To understand variables in more detail,
#
# * **hotel:-** The name of the hotel where the booking was made.
# * **is_canceled:-** Whether the booking was canceled (1) or not (0).
# * **lead_time:-** The number of days between booking and arrival.
# * **arrival_date_year:-** The year of the arrival date.
# * **arrival_date_month:-** The month of the arrival date.
# * **arrival_date_week_number:-** The week number of the year for the arrival date.
# * **arrival_date_day_of_month:-** The day of the month for the arrival date.
# * **stays_in_weekend_nights:-** Number of weekend nights (Saturday or Sunday) the guest stayed.
# * **stays_in_week_nights:-** Number of weekday nights (Monday to Friday) the guest stayed.
# * **adults:-** Number of adults in the booking.
# * **children:-** Number of children in the booking.
# * **babies:-** Number of babies in the booking.
# * **meal:-** The type of meal booked.
# * **country:-** The country of origin of the guest.
# * **market_segment:-** The market segment the booking belongs to.
# * **distribution_channel:-** The distribution channel used for the booking.
# * **is_repeated_guest:-** Whether the guest is a repeated guest (1) or not (0).
# * **previous_cancellations:-** Number of previous booking cancellations by the guest.
# * **previous_bookings_not_canceled:-** Number of previous bookings that were not canceled by the guest.
# * **reserved_room_type:-** The originally booked room type.
# * **assigned_room_type:-** The room type assigned at check-in.
# * **booking_changes:-** Number of changes made to the booking.
# * **deposit_type:-** The type of deposit made for the booking.
# * **agent:-** ID of the travel agency that made the booking.
# * **company:-** ID of the company if the booking was made on behalf of one.
# * **days_in_waiting_list:-** Number of days the booking was on the waiting list before being confirmed.
# * **customer_type:-** Type of booking (Contract, Group, Transient, Transient-Party).
# * **adr:-** Average Daily Rate (total spend divided by number of nights).
# * **required_car_parking_spaces:-** Number of car parking spaces requested.
# * **total_of_special_requests:-** Number of special requests made by the guest.
# * **reservation_status:-** Current status of the reservation.
# * **reservation_status_date:-** Date at which the last status was set.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for column in data.columns: #use a loop to iterate over columns and find unique values
  unique_value = data[column].unique()
  print(f'Unique value in {column}\n',unique_value)
# Out:
# Unique value in hotel
#  ['Resort Hotel' 'City Hotel']
# Unique value in is_canceled
#  [0 1]
# Unique value in lead_time
#  [342 737   7  13  14   0   9  85  75  23  35  68  18  37  12  72 127  78
#   48  60  77  99 118  95  96  69  45  40  15  36  43  70  16 107  47 113
#   90  50  93  76   3   1  10   5  17  51  71  63  62 101   2  81 368 364
#  324  79  21 109 102   4  98  92  26  73 115  86  52  29  30  33  32   8
#  100  44  80  97  64  39  34  27  82  94 110 111  84  66 104  28 258 112
#   65  67  55  88  54 292  83 105 280 394  24 103 366 249  22  91  11 108
#  106  31  87  41 304 117  59  53  58 116  42 321  38  56  49 317   6  57
#   19  25 315 123  46  89  61 312 299 130  74 298 119  20 286 136 129 124
#  327 131 460 140 114 139 122 137 126 120 128 135 150 143 151 132 125 157
#  147 138 156 164 346 159 160 161 333 381 149 154 297 163 314 155 323 340
#  356 142 328 144 336 248 302 175 344 382 146 170 166 338 167 310 148 165
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# after viweing the dataset and null values we need to fill null values with '0' for numeric type and unknown for object type
data.fillna({'children': 0, 'country': 'Unknown', 'agent': 0, 'company': 0}, inplace=True)

# for ease of analyse we have merge adult,children,babies in a new column name person
data['person'] = data['adults'] + data['children'] + data['babies']

# converting date data to datatime format
data['reservation_status_date'] = pd.to_datetime(data['reservation_status_date'], format = '%Y-%m-%d')

# merging weekend stay and week stay into total stay
data['total_stays'] = data['stays_in_weekend_nights']+data['stays_in_week_nights']
data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  company  \
# 0                        0                     0       2  ...      0.0
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %%
# Changing type of data
data['person'] = data['person'].fillna(0).astype('int64')
data = data[np.isfinite(data['person'])]
data['person'] = data['person'].astype('int64')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 119390 entries, 0 to 119389
# Data columns (total 34 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119390 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# # **Manupulation I have done:**
# * Handling Missing Values:
#
# I have identified missing values in columns like children, country, agent, and company.
# I have filled missing values with appropriate placeholders or strategies, such as replacing missing children counts with 0, missing countries with 'Unknown', and missing agent/company IDs with 0.
#
# * Create new column:
#
# I have create a new column that merge all the data from adult, children and babies into person and stay in weekend and week days into total stays.
#
# * Changing Type:
#
# Changing type of data such as reservation data from int to datetime and person form float to int.
#
#
# #  **Insights are as follows:**
#
# * Cancellation Patterns:
#
# Analyze the cancellation rate and identify factors that are correlated with higher cancellation rates, such as lead time, deposit type, or previous cancellations.
# * Booking Behavior:
#
# Understand the distribution of booking lead times and identify any trends related to the booking behavior of guests.
# * Seasonal Trends:
#
# Investigate whether there are certain months or periods during the year with higher booking rates or higher cancellation rates.
# * Guest Types:
#
# Explore the distribution of customer types (e.g., transient, group) and their preferences, including average daily rates (ADR) and special requests.
# * Room Allocation:
#
# Analyze the differences between reserved room types and assigned room types to identify any patterns or potential issues.
# * Booking Channels:
#
# Investigate which distribution channels and market segments contribute the most to bookings and whether they differ in terms of cancellation rates.
# * Length of Stay:
#
# Understand the distribution of the length of stay and whether it's related to certain customer segments or booking types.
# * Special Requests:
#
# Explore the impact of special requests on booking cancellations and ADR.
# * Customer Nationalities:
#
# Analyze the countries of origin of guests and their booking behaviors, potentially identifying trends based on different nationalities.
# * Agent and Company Impact:
#
# Investigate whether bookings made through agents or companies have different patterns compared to direct bookings.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %% [markdown]
# #### **Q1. In which month how many cancellation are made?**

# %%
# Chart - 1 visualization code
plt.figure(figsize=(10, 6)) #This control our chart hight and width
sns.countplot(x='arrival_date_month', hue='is_canceled', data=data)
plt.title('Cancellation Rate by Month')
plt.xticks(rotation=90) #This rotate the lines in x axis
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The choice of the specific chart in my previous response was based on the context of the dataset, which involves analyzing the cancellation rate by month. Here's the rationale behind using a 'sns.countplot' chart for this scenario:
#
# Cancellation Rate by Month:
# The sns.countplot chart is used to visualize the frequency of occurrences of categorical variables.
# The x-axis represents the months, and the hue (color) of the bars represents whether a booking was canceled (is_canceled value 1) or not (is_canceled value 0).
# This chart provides a clear visual comparison of cancellation rates across months.
# So I choose this chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the chart that displays the cancellation rate by month, I discover that certain months have higher cancellation rates compared to others.
# For instance, it can be seen that cancellation rates are higher during March to August, which could indicate that cancellations are more frequent during the vacation season.
# Conversely, it is noticed a lower cancellation rates during November to Febuary.
# This insight could inform strategies for managing reservations, staffing, and pricing during different times of the year.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The potential positive or negative business impact of insights gained from data analysis depends on the nature of the insights, the context of the business, and the actions taken in response. Let's consider the potential insights from the cancellation rate by month chart and their possible implications:
#
# Insight: **Seasonal Variation in Cancellation Rates (Positive/Negative Impact)**
#
# * Positive Impact:
#
# If the business can identify the months with higher cancellation rates (e.g., peak vacation season) and take proactive measures, such as offering flexible cancellation policies, targeted promotions, or overbooking strategies, this can lead to improved customer satisfaction, higher occupancy rates, and increased revenue during peak periods.
# * Negative Impact:
#
# On the other hand, if the business doesn't adjust its strategies to address the higher cancellation rates during peak months, it might face revenue losses due to unused room inventory. This could also result in disappointed customers who expected to find rooms available.
# Ultimately, the impact depends on how the insights are used to drive decision-making. For example, if the insights lead to actions that enhance customer experience and optimize resource utilization, the impact is likely to be positive. Conversely, if the insights are not acted upon or lead to decisions that don't align with customer needs, negative outcomes are possible.

# %% [markdown]
# #### Chart - 2

# %% [markdown]
# #### **Q2. What are the preference of customer in choosing the Meal type?**

# %%
# Chart - 2 visualization code
# person vs meal
# Univariate - Numerical
plt.figure(figsize=(8, 6))
sns.countplot(data=data, x='meal')
plt.xlabel('Meal Type')
plt.ylabel('Count of People (Person)')
plt.title('Count of People by Meal Type')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The specific chart chosen is a countplot, which is a type of bar chart. It's suitable for visualizing the distribution of categorical data, such as different meal types in this case. Each bar represents a category (meal type), and the height of the bar represents the count of people who selected each meal type.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows the distribution of guests based on their meal preferences (meal type). From the chart, it can be observe the following insights:
#
# * BB (Bed & Breakfast): This meal type is the most popular choice among guests, as it has the highest count of people.
#
# * HB (Half Board): The count of people who chose the Half Board meal type is significantly lower than BB but still noticeable.
#
# * FB (Full Board): Very few guests opted for the Full Board meal type, as indicated by the lowest bar.
#
# * SC (Self Catering): It can be seen that SC type meal has been ordered by significantly low visitors.
#
# * Undefined: There is also a category labeled "Undefined," which is unknown to us or data is not present.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impact:**
#
# The gained insights can help the hotel management in several ways:
#
# * Menu Planning: The hotel can adjust its menu and food service based on the popularity of meal types. Since BB is the most preferred, the hotel can focus on offering a wider range of breakfast options.
#
# * Resource Allocation: Understanding the distribution of meal preferences can help with resource allocation, such as staff scheduling and food inventory management.
#
# * Marketing: The hotel can use this information in its marketing efforts, promoting the meal types that are less popular to attract more guests to try them.
#
# **Negative Growth:**
#
# The chart doesn't explicitly show negative growth. However, if the hotel notices a consistent decline in the popularity of a particular meal type (e.g., FB), it might consider reevaluating its offerings or marketing strategies for that meal type. Negative growth could potentially occur if a meal type becomes increasingly unpopular, leading to decreased revenue in that category.

# %% [markdown]
# #### Chart - 3

# %% [markdown]
# #### **Q3. What can be find about the distribution of Average Daily Rates (ADR) for the bookings in the dataset?**

# %%
# Chart - 3 visualization code
plt.figure(figsize=(8, 6))
sns.histplot(data=data, x='adr', kde=True)
plt.xlabel('ADR (Average Daily Rate)')
plt.ylabel('Frequency')
plt.title('Distribution of ADR')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The histogram with a KDE is a suitable choice for visualizing the distribution of a continuous numerical variable, in this case, the Average Daily Rate (ADR). It helps to understand the frequency and pattern of ADR values, including their central tendency and spread

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * ADR Distribution: The chart shows the distribution of ADR (Average Daily Rate) values. ADR represents the average price paid by guests for a night's stay.
#
# * Peak at Lower Rates: There is a peak in the frequency of ADR values at the lower end of the spectrum, indicating that a significant number of bookings are made at lower rates.
#
# * Long Right Tail: The chart exhibits a long right tail, indicating that there are a few instances of exceptionally high ADR values, which are less frequent but can significantly impact revenue.
#
# * Normal-Like Distribution: The KDE curve suggests that the ADR values have a roughly normal-like distribution with a slight positive skew.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impact:**
#
# The gained insights can help the hotel management in several ways:
#
# * Pricing Strategy: Understanding the distribution of ADR values can inform the hotel's pricing strategy. It can help optimize rates to attract more guests while maximizing revenue.
#
# * Revenue Forecasting: By knowing the distribution of ADR values, the hotel can make more accurate revenue forecasts and set revenue goals.
#
# * Marketing: The hotel can use this information in marketing campaigns, such as promoting special offers during periods with lower ADR to attract more bookings.
#
# **Negative Growth:**
#
# While the chart doesn't explicitly show negative growth, there are potential negative implications:
#
# * Impact of Low Rates: If a significant portion of bookings consistently falls into the lower ADR range, it may lead to reduced revenue and profitability, especially if operational costs are high. This could negatively impact the hotel's financial performance.
#
# * Competitive Pricing: The long right tail with high ADR values could indicate competition from luxury or high-end hotels. If these high ADR values are due to competitors offering superior services or amenities, it may indicate a need for the hotel to enhance its offerings to compete effectively.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code

# Arrival Date Day of Month vs Days in Waiting List Bivariate - Numerical vs Numerical
custom_pallet = {'Resort Hotel':'green', 'City Hotel':'red'}
plt.figure(figsize = (10,6))
sns.scatterplot(data=data, x='arrival_date_day_of_month', y='days_in_waiting_list', hue='hotel', palette=custom_pallet, alpha=0.5)
plt.xlabel('Arrival Day of Month')
plt.ylabel('Days in Waiting List')
plt.title('Relationship between Arrival Day and Waiting List Days')
plt.legend(title='Hotel Type')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatterplot is chosen for visualizing the relationship between two numerical variables, in this case, 'arrival date day of month' and 'days in waiting list.' The 'hue' parameter is used to differentiate the points by the 'hotel' variable, allowing us to see how the two variables relate differently for different hotel types.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Arrival Day vs. Waiting List Days: The scatterplot shows the relationship between the day of the month when guests arrive and the number of days they spend on the waiting list before their stay.
#
# * Different Patterns for Hotel Types: The points are color-coded by hotel type (Resort Hotel in green, City Hotel in red). We can observe that there are differences in the distribution of points between the two hotel types.
#
# * Resort Hotel: For Resort Hotels (green points), there appears to be less clustering around specific arrival days, and the waiting list days are generally low. This suggests that guests at Resort Hotels tend to have shorter waiting times.
#
# * City Hotel: For City Hotels (red points), there seems to be more clustering around specific arrival days, and there is a wider range of waiting list days. This suggests that guests at City Hotels may have longer waiting times, and there might be specific arrival days with high demand.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impact:**
#
# The gained insights can help the hotel management in several ways:
#
# * Demand Management: Understanding the relationship between arrival day and waiting list days can help hotels anticipate and manage peak demand periods more effectively. For example, they can allocate more resources (staff, rooms) during days with high demand to reduce waiting times.
#
# * Customer Experience: Shorter waiting times can lead to a better guest experience, which can result in higher customer satisfaction and potentially more repeat bookings.
#
# * Marketing Strategies: Hotels can use this information to adjust their marketing strategies, such as offering promotions or incentives to guests who book on days with historically longer waiting times.
#
# **Negative Growth:**
#
# * While the chart doesn't explicitly show negative growth, there are potential negative implications:
#
# * Guest Frustration: Longer waiting times, especially on specific days, may lead to guest frustration and negative reviews. This can impact the hotel's reputation and lead to lower occupancy rates in the long run.
#
# * Lost Revenue: If guests experience extended waiting times and choose to cancel their bookings, it can result in lost revenue for the hotel. Additionally, negative guest experiences can deter future bookings.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
plt.figure(figsize=(6, 4))
sns.boxplot(x='is_canceled', y='lead_time', data=data)
plt.title('Lead Time vs Cancellation')
plt.xlabel('Cancellation')
plt.ylabel('Lead Time')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A boxplot is chosen to visualize the distribution of 'lead_time' (the number of days between booking and arrival) for two categories of 'is_canceled' (cancellation status: 0 for not canceled, 1 for canceled). Boxplots are effective for comparing the distribution of a numerical variable across different categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Lead Time vs. Cancellation Status: The boxplot displays the distribution of lead times for both canceled (1) and not canceled (0) bookings.
#
# * Lead Time for Canceled Bookings: For canceled bookings (1), the boxplot shows that the median lead time is relatively shorter, as indicated by the lower boundary of the box. However, there are also outliers with very long lead times for canceled bookings, as indicated by the whiskers.
#
# * Lead Time for Not Canceled Bookings: For not canceled bookings (0), the boxplot shows a higher median lead time compared to canceled bookings. The distribution appears more spread out, with some outliers having very long lead times.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Lead Time vs. Cancellation Status: The boxplot displays the distribution of lead times for both canceled (1) and not canceled (0) bookings.
#
# * Lead Time for Canceled Bookings: For canceled bookings (1), the boxplot shows that the median lead time is relatively shorter, as indicated by the lower boundary of the box. However, there are also outliers with very long lead times for canceled bookings, as indicated by the whiskers.
#
# * Lead Time for Not Canceled Bookings: For not canceled bookings (0), the boxplot shows a higher median lead time compared to canceled bookings. The distribution appears more spread out, with some outliers having very long lead times.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
# (Bivariate - Categorical vs Categorical)
sns.countplot(data=data, x='hotel', hue='customer_type')
plt.xlabel('Hotel Type')
plt.ylabel('Count')
plt.title('Distribution of Customer Type by Hotel')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A countplot with hue is an appropriate choice for comparing the distribution of one categorical variable across different categories of another categorical variable. In this case, it allows you to explore how customer types are distributed among different hotel types.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Distribution of Customer Types by Hotel: The chart displays the count of each customer type (e.g., Transient, Contract, Group) for each hotel type (e.g., Resort Hotel, City Hotel).
#
# Transient Guests: The most common customer type for both Resort Hotels and City Hotels is "Transient," as indicated by the tallest bars in both categories.
#
# Contract and Group Guests: While Transient guests dominate, there are also Contract and Group guests in both types of hotels, with City Hotels having a slightly higher proportion of Contract guests.
#
# Resort Hotel vs. City Hotel: Resort Hotels have a larger proportion of "Transient" guests compared to City Hotels, which suggests that transient travelers may prefer resort-style accommodations. Conversely, City Hotels have a relatively higher proportion of "Contract" guests.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impact:**
#
# The gained insights can help the hotel management in several ways:
#
# * Targeted Marketing: Understanding the distribution of customer types can inform targeted marketing strategies. For example, Resort Hotels can tailor their marketing to attract more transient travelers, while City Hotels can focus on attracting contract guests.
#
# * Pricing Strategies: Different customer types may have different price sensitivities and booking behaviors. Hotels can adjust their pricing strategies based on these insights to maximize revenue.
#
# * Service Customization: Hotels can customize their services and amenities to better cater to the predominant customer types. For example, City Hotels might focus on business-oriented services for contract guests.
#
# **Negative Growth:**
#
# While the chart itself doesn't show negative growth, there are potential negative implications:
#
# * Customer Satisfaction: Focusing too heavily on one customer type at the expense of others may lead to dissatisfaction among less-represented customer types. For example, if a City Hotel primarily targets contract guests and neglects transient guests, it may miss out on revenue from the latter group and potentially receive negative feedback.
#
# * Market Competition: If customer preferences change, hotels that are too focused on one type of guest may lose competitiveness. For instance, if there's a shift in the market towards more transient travelers, City Hotels heavily reliant on contract guests may face challenges.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
plt.figure(figsize=(10, 5))
sns.countplot(data=data, x='market_segment')
plt.title('Market Segment Distribution')
plt.xlabel('Market Segment')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A countplot is appropriate for showing the distribution of categorical data. In this case, it helps visualize the frequency of each market segment in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Market Segment Distribution: The chart displays the distribution of guests across different market segments. Each bar represents a specific market segment, and the height of the bar indicates the count of guests belonging to that segment.
#
# Online Travel Agents (TA/TO): The "Online TA/TO" segment has the highest count of guests, making it the most common way through which guests made their bookings.
#
# Offline Travel Agents (TA/TO): The "Offline TA/TO" segment also has a significant number of guests but is less common than the "Online TA/TO" segment.
#
# Other Segments: Other segments, such as "Direct," "Corporate," and "Complementary," have comparatively lower counts.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impact:**
#
# The gained insights can help the hotel management in several ways:
#
# * Marketing Strategies: The hotel can tailor its marketing strategies to target the most common market segments, such as "Online TA/TO," to attract more guests from these channels.
#
# * Resource Allocation: Knowledge of the dominant market segments can help the hotel allocate resources efficiently. For instance, if "Online TA/TO" bookings are common, the hotel can invest in online booking platforms and customer support for these guests.
#
# * Partnerships: If certain segments, such as "Corporate," are of strategic importance, the hotel can establish partnerships with corporate clients to secure long-term bookings.
#
# **Negative Growth:**
#
# While the chart itself doesn't show negative growth, there are potential negative implications:
#
# * Over-Reliance on a Single Segment: If the hotel becomes overly reliant on a single market segment, such as "Online TA/TO," it could be vulnerable to market changes or shifts in guest preferences. If the popularity of a particular segment declines, it may lead to a decrease in bookings and revenue.
#
# * Market Competition: If many hotels target the same dominant market segments, it can result in intense competition and potentially lower profit margins.
#
# * Diversification: Over-reliance on a specific market segment may limit the hotel's ability to diversify its guest base. Diversification can be important for stability, especially during economic downturns or changes in market conditions.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
# (Multivariate - Categorical vs Categorical)
sns.countplot(data=data, x='hotel', hue='deposit_type')
plt.xlabel('Hotel Type')
plt.ylabel('Count')
plt.title('Deposit Type by Hotel')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A countplot with hue is a suitable choice for comparing the distribution of one categorical variable across different categories of another categorical variable. In this case, it allows you to explore how deposit types are distributed among different hotel types.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Deposit Type by Hotel: The chart displays the count of each deposit type (e.g., No Deposit, Non-Refund, Refundable) for each hotel type (e.g., Resort Hotel, City Hotel).
#
# No Deposit: "No Deposit" is the most common deposit type for both Resort Hotels and City Hotels, as indicated by the tallest bars in both categories.
#
# Non-Refund: "Non-Refund" is the second most common deposit type for both hotel types, with City Hotels having a slightly higher count of non-refundable bookings.
#
# Refundable: "Refundable" deposit types are less common in both hotel types, with Resort Hotels having a higher count of such bookings compared to City Hotels.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impact:**
#
# The gained insights can help the hotel management in several ways:
#
# * Deposit Policies: Understanding the distribution of deposit types can inform the hotel's deposit policies. For example, hotels can offer different pricing or booking conditions based on the deposit type to attract more guests.
#
# * Risk Management: Hotels can assess the level of financial risk associated with different deposit types. For example, non-refundable bookings may carry less risk of cancellation, while refundable bookings may provide flexibility for guests.
#
# * Revenue Management: Knowledge of deposit types can be used in revenue management strategies. For instance, hotels can adjust pricing for refundable and non-refundable bookings to optimize revenue.
#
# **Negative Growth:**
#
# While the chart itself doesn't show negative growth, there are potential negative implications:
#
# * Loss of Revenue: If a hotel heavily relies on non-refundable bookings and experiences a high number of cancellations or changes in plans by guests, it may lead to revenue loss due to forfeited deposits.
#
# * Guest Satisfaction: Non-refundable bookings may lead to dissatisfaction if guests encounter unexpected circumstances and cannot cancel or modify their bookings. This can result in negative reviews and reduced customer loyalty.
#
# * Competitive Pricing: If competitors offer more flexible deposit policies, hotels with stricter policies may lose bookings to competitors, especially during uncertain times or when travelers seek flexibility.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
# Bivariate Analysis (Categorical vs Categorical)
plt.figure(figsize=(12, 6))
custom_p = {'Resort Hotel':'Violet', 'City Hotel':'Pink'}
sns.countplot(data=data, x='arrival_date_month', hue='hotel',palette=custom_p, alpha = 0.7)
plt.xlabel('Arrival Month')
plt.ylabel('Count')
plt.title('Hotel vs Arrival Month')
plt.xticks(rotation=90)
plt.legend(title='Hotel Type')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A countplot with hue is a suitable choice for comparing the distribution of one categorical variable (arrival month) across different categories of another categorical variable (hotel type).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Hotel vs. Arrival Month: The chart displays the count of hotel bookings for each month of the year, with separate bars for Resort Hotels and City Hotels.
#
# * Seasonal Variation: The chart shows that both types of hotels experience seasonal variation in bookings. For both Resort and City Hotels, the summer months (June, July, and August) have the highest booking counts, indicating peak tourist seasons.
#
# * City Hotel Dominance: City Hotels consistently have higher booking counts throughout the year compared to Resort Hotels, suggesting that City Hotels are in demand year-round.
#
# * Resort Hotel Peaks: While City Hotels maintain relatively consistent booking counts, Resort Hotels experience more significant peaks during the summer months.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impact:**
#
# The gained insights can help the hotel management in several ways:
#
# * Seasonal Pricing: Hotels can adjust their pricing strategies based on the seasonal variation in bookings. They can offer competitive rates during off-peak months to attract guests and maximize revenue during peak seasons.
#
# * Resource Allocation: Understanding peak booking months allows hotels to allocate resources efficiently, such as staff and room availability. Additional staff can be scheduled during high-demand months.
#
# * Marketing Campaigns: Hotels can plan marketing campaigns targeting specific months to attract guests. For example, they can promote special summer packages for Resort Hotels during peak summer months.
#
# **Negative Growth:**
#
# While the chart doesn't explicitly show negative growth, there are potential negative implications:
#
# * Overcrowding: Peak booking months can lead to overcrowding in hotels, potentially affecting the guest experience. Hotels need to manage guest expectations and ensure they have adequate facilities and staff to handle the influx of guests during peak seasons.
#
# * Off-Peak Challenges: City Hotels may face challenges in attracting guests during off-peak months when booking counts are lower. They need to develop strategies to maintain profitability and occupancy levels during these times.
#
# * Competitive Challenges: Competing with other hotels during peak seasons can be challenging, and hotels may engage in price wars that can lead to lower profit margins.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
sum_person_by_hotel = data.groupby('hotel')['person'].sum().reset_index()
# Univariate Analysis
# Create a bar plot to visualize the sum of people (person) for each hotel type
plt.figure(figsize=(4, 4))
sns.barplot(data=sum_person_by_hotel, x='hotel', y='person')
plt.xlabel('Hotel Type')
plt.ylabel('Sum of People (Person)')
plt.title('Sum of People by Hotel Type')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The bar plot is chosen to visualize the total sum of people (person) for each hotel type in a straightforward and easily interpretable manner. It allows for a direct comparison between the two hotel types.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Sum of People by Hotel Type: It shows the total number of people (person) for each hotel type.
#
# * City Hotel Dominance: City Hotels have a significantly higher total sum of people compared to Resort Hotels. This suggests that City Hotels accommodate a larger number of guests in total.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impact:**
#
# The gained insight can help the hotel management in several ways:
#
# * Resource Allocation: Understanding the total number of guests accommodated by each hotel type allows for better resource allocation, including staff, room availability, and service provisioning.
#
# * Revenue Assessment: Hotels can assess their revenue generation based on the total number of guests accommodated. City Hotels, with a higher number of guests, may generate more revenue but should also consider factors like room rates and occupancy rates.
#
# * Marketing Strategies: The insight can inform marketing strategies, helping hotels target their marketing efforts towards their predominant guest type.
#
# **Negative Growth:**
#
# While the chart itself doesn't show negative growth, there are potential negative implications:
#
# * Room Availability: City Hotels accommodating a larger number of guests may face challenges related to room availability during peak seasons. This could lead to overbooking issues or guest dissatisfaction.
#
# * Service Quality: Maintaining a high level of service quality for a larger number of guests can be challenging. City Hotels should ensure that they have adequate staff and resources to meet the needs of their guests.
#
# * Competitive Pressure: Resort Hotels, with a lower total sum of people, may face competitive pressure to attract more guests and increase revenue. This could lead to pricing wars or increased marketing expenses.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
waiting_bookings = data[data['days_in_waiting_list'] !=0]  # Selecting bookings with non zero waiting time

fig, axes = plt.subplots(1, 2, figsize=(14,6))
sns.kdeplot(ax=axes[0],x = 'days_in_waiting_list', hue = 'is_canceled' , data = waiting_bookings)
sns.kdeplot(ax = axes[1], x = data['lead_time'], hue = data['is_canceled'])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * KDE Plot for 'days in waiting list': This chart was chosen to visualize the distribution of 'days in waiting list' for bookings with non-zero waiting times. It uses color (hue) to differentiate between canceled and non-canceled bookings, allowing for an examination of how waiting time relates to cancellations.
#
# * KDE Plot for 'lead time': This chart was chosen to visualize the distribution of 'lead time,' which represents the number of days between booking and arrival. It also uses color (hue) to differentiate between canceled and non-canceled bookings, allowing for an examination of how lead time impacts cancellations.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * KDE Plot for 'days_in_waiting_list':
#
# The chart on the left shows that bookings with a non-zero waiting time tend to have two peaks in the distribution, suggesting that there are two clusters of waiting times.
# Canceled bookings (indicated by the blue curve) tend to have shorter waiting times, with a peak at the lower end of the waiting time range.
# Non-canceled bookings (indicated by the orange curve) have a broader distribution of waiting times, with a peak at a slightly higher waiting time.
#
# * KDE Plot for 'lead_time':
#
# The chart on the right shows that lead time has a right-skewed distribution, with a peak at lower lead times, indicating that many bookings are made closer to the arrival date.
# Canceled bookings (indicated by the blue curve) tend to have shorter lead times, with a peak at the lower end of the lead time range.
# Non-canceled bookings (indicated by the orange curve) have a broader distribution of lead times, with a peak at a slightly higher lead time.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impact:**
#
# The gained insights can help in several ways:
#
# * Booking Management: Hotels can use this information to manage their booking policies and optimize the waiting time and lead time to reduce cancellations.
#
# * Cancellation Prediction: Understanding how waiting time and lead time influence cancellations can aid in developing predictive models to identify bookings at higher risk of cancellation.
#
# * Revenue Management: Hotels can adjust their pricing strategies based on lead time and waiting time to optimize revenue, such as offering discounts for early bookings.
#
# **Negative Growth:**
#
# The insights do not inherently lead to negative growth but highlight potential challenges:
#
# * Cancellation Management: High cancellation rates for bookings with short waiting times or lead times can lead to revenue loss and inefficient room allocation. Hotels may need to refine their policies to address this.
#
# * Competitive Pricing: Adjusting prices based on lead time and waiting time can
# be challenging if competitors offer more flexible booking terms, potentially leading to competitive pressures.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
max_stays = data.groupby('country')['total_stays'].max().reset_index()

# Filter the DataFrame for the top 10 countries
top_10_countries_max_stays = max_stays.nlargest(10, 'total_stays')

# Create a bar plot to visualize stays in week nights by country
plt.figure(figsize=(8, 4))
sns.barplot(data=top_10_countries_max_stays, x='total_stays', y='country', errorbar=None, estimator=sum)
plt.xlabel('Country')
plt.ylabel('Total Stays Per Nights')
plt.title('Top 10 Countries with Maximum Stays Per Nights')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The bar plot is chosen because it effectively displays the total stays per weeknight for the top 10 countries, allowing for a straightforward comparison of these countries in terms of maximum stays per weeknight.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Top 10 Countries: The chart highlights the top 10 countries with the maximum stays per weeknight. These countries are ranked based on the highest total stays per weeknight.
#
# * Variation in Stays: The chart shows that there is variation in the total stays per weeknight among these top 10 countries. Some countries have significantly higher total stays, while others have lower total stays.
#
# * Leaders in Stays: The countries with the highest total stays per weeknight are identified, providing insights into which countries contribute the most to this metric.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impact:**
#
# The gained insights can help in several ways:
#
# * Market Focus: Hotels can use this information to focus their marketing efforts on countries with high total stays per weeknight, potentially attracting more guests from these countries.
#
# * Resource Allocation: Understanding which countries have the highest stays can guide resource allocation decisions, such as multilingual staff and cultural accommodations to enhance the guest experience for these markets.
#
# * Partnerships: Hotels can explore partnerships with travel agencies or platforms that are popular in these high-stay countries to increase visibility and bookings.
#
# **Negative Growth:**
#
# While the chart doesn't inherently lead to negative growth, there are potential negative implications:
#
# * Market Dependency: Overreliance on a small number of countries with high stays can pose a risk. Economic or political changes in these countries could lead to a sudden decline in bookings from those markets.
#
# * Competitive Challenges: Competitors may also target these high-stay countries, leading to competitive pressures and potentially affecting pricing strategies.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
canceled_counts = data['is_canceled'].value_counts()

# Create a pie chart
plt.figure(figsize=(6, 6))
plt.pie(canceled_counts, labels=['Not Canceled', 'Canceled'], autopct='%1.1f%%', startangle=90, colors=['violet', 'pink'])
plt.title('Cancellation Status')

# Display the pie chart
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie chart is chosen because it effectively displays the composition of a categorical variable (cancellation status) as a part-to-whole relationship. It allows for a quick and easy visualization of the proportion of cancellations in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Cancellation Status: The pie chart visually represents the distribution of cancellation status in the dataset, showing the percentage of bookings that were canceled and not canceled.
#
# Proportion of Cancellations: The chart makes it clear that cancellations (the pink portion) form a significant proportion of the dataset, indicating that a considerable number of bookings have been canceled.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impact:**
#
# The gained insight can help in several ways:
#
# * Booking Management:
#
# Hotels can use this information to assess the cancellation rate and develop strategies to reduce cancellations. This might include refining booking policies or offering incentives to encourage non-canceled bookings.
#
# * Revenue Optimization:
#
# Understanding the proportion of cancellations can assist in revenue optimization by adjusting pricing or offering promotions to attract and retain more bookings.
#
# * Customer Experience:
#
# Hotels can focus on improving the guest experience to encourage more non-canceled bookings. Satisfied guests are less likely to cancel their reservations.
#
# * Negative Growth:
#
# While the chart itself doesn't lead to negative growth, there are potential negative implications:
#
# * Revenue Impact:
#
# A high proportion of cancellations can lead to revenue loss, especially if the hotel is unable to fill canceled rooms with new bookings.
#
# * Operational Challenges:
#
# Managing a high cancellation rate can be operationally challenging, as it requires constant adjustments to room allocations and staffing.
#
# * Competitive Pressures:
#
# If competitors have lower cancellation rates, they may gain a competitive advantage in terms of revenue stability.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
# Univariate Analysis
num_data = data[['lead_time','previous_cancellations','previous_bookings_not_canceled','booking_changes','days_in_waiting_list','adr','required_car_parking_spaces','total_of_special_requests','total_stays','person']]
corrmat = num_data.corr()
f, ax = plt.subplots(figsize=(12, 7))
sns.heatmap(corrmat,annot = True,fmt='.2f', annot_kws={'size': 10},  vmax=.8, square=True);

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A heatmap is chosen because it is an effective way to visualize the correlations between multiple numerical variables. In this case, it shows how each numerical variable is related to others in terms of their correlation coefficients.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Correlation Coefficients:** The heatmap displays correlation coefficients between pairs of numerical variables. These coefficients indicate the strength and direction of the linear relationship between variables. Positive values indicate a positive correlation, negative values indicate a negative correlation, and values close to zero indicate little or no correlation.
#
# **Strong Positive Correlations:** Darker and more intense colors on the heatmap represent stronger correlations. For example, if two variables have a strong positive correlation, you will see a dark square in the corresponding cell.
#
# **Strong Negative Correlations:** Similarly, dark squares in the opposite direction (diagonally mirrored) represent strong negative correlations.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
plt.figure(figsize=(10, 10))
numerical_columns = ['lead_time','previous_cancellations', 'previous_bookings_not_canceled', 'booking_changes', 'person',] #few numerical columns selected for visualization
sns.pairplot(data[numerical_columns], diag_kind='kde')
plt.suptitle('Pair Plot of Selected Numerical Features', y=1.02)
plt.xticks(rotation=90)
plt.yticks(rotation=90)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pair plot is chosen because it provides a comprehensive view of the relationships between multiple numerical variables. It displays scatterplots for pairs of variables and histograms for each variable on the diagonal, making it useful for both univariate and bivariate analysis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Scatterplots:** The scatterplots in the lower part of the pair plot show the relationships between pairs of numerical variables. They help identify patterns, trends, and correlations between variables.
#
# **Diagonal Histograms:** The histograms on the diagonal display the distribution of each individual numerical variable. They show the shape and spread of each variable's values.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# I would suggest the client to take into consideration the following points:
#
# **Optimizing Cancellation Rates:**
#
# Implement targeted marketing campaigns or promotions during historically high cancellation months to incentivize guests to keep their reservations.
#
# **Enhancing Meal Offerings:**
#
# Based on meal type preferences, refine menu offerings or introduce special packages to cater to guests' preferences.
#
# **Pricing Strategy:**
#
# Regularly review and adjust Average Daily Rates (ADR) to align with market demand, seasonal trends, and competitors' pricing.
#
# **Room Allocation and Staffing:**
#
# Adjust staffing schedules and room allocation strategies based on arrival day patterns and waiting list data to ensure optimal resource utilization.
#
# **Booking Policies:**
#
# Consider implementing more stringent booking deadlines or deposit requirements for reservations with long lead times, which may reduce cancellations.
#
# **Targeted Marketing for Customer Segments:**
#
# Tailor marketing efforts to specific customer types, offering promotions or services that align with their preferences.
#
# **Market Segment Targeting:**
#
# Focus marketing efforts on the most lucrative market segments to maximize revenue and occupancy rates.
#
# **Deposit Policies:**
#
# Review and potentially revise deposit policies to cater to the prevalent deposit types, ensuring they align with customer preferences.
#
# **Seasonal Strategies:**
#
# Based on the Hotel vs Arrival Month analysis, develop targeted marketing campaigns or promotions to capitalize on seasonal booking patterns.
#
# **Optimize Staffing and Resources:**
#
# Use the Sum of People by Hotel Type data to effectively allocate staff and resources based on expected guest volumes.
#
# **Refine Booking Policies:**
#
# Based on Waiting List and Lead Time Analysis, refine booking policies to ensure they are customer-friendly while minimizing cancellations.
#
# **International Marketing:**
#
# Target marketing efforts towards countries with the highest stays per nights to attract and retain guests from these regions.
#
# **Cancellation Mitigation:**
#
# Implement strategies to reduce cancellations, such as flexible booking options, reminder emails, or loyalty programs.
#
# **Pricing and Service Refinement:**
#
# Based on the Correlation Heatmap, adjust pricing strategies and service offerings to align with customer preferences and needs.
#
# **Identify Trends for Improvement:**
#
# Use insights from the Pair Plot to identify potential trends that can inform pricing, marketing, or service adjustments.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# In conclusion, the analysis of the hotel booking data provides valuable insights into various aspects of the business:
#
# **Cancellation Rates by Month:**
#
# Cancellation rates vary by month, suggesting the need for targeted marketing
# and promotional efforts during high cancellation periods.
#
# **Meal Type Preferences:**
#
# Understanding guest preferences for meal types can guide menu offerings and special packages to enhance guest satisfaction.
#
# **ADR Distribution:**
#
# The distribution of Average Daily Rates (ADR) highlights the range of pricing strategies employed by the hotel.
#
# **Arrival Day and Waiting List:**
#
# There is a relationship between the day of arrival and the length of time guests spend on the waiting list. This can inform staffing and room allocation strategies.
#
# **Lead Time vs. Cancellations:**
#
# Longer lead times tend to have a higher likelihood of cancellations, suggesting the need for flexible booking policies or deposit requirements.
# Customer Type Distribution by Hotel:
#
# Understanding the distribution of customer types across hotel types can inform marketing efforts and service customization.
#
# **Market Segment Distribution:**
#
# Identifying the most prominent market segments allows for targeted marketing efforts to maximize revenue.
#
# **Deposit Type by Hotel:**
#
# Different deposit policies are preferred for different hotel types, indicating the need for tailored booking policies.
# **Hotel vs. Arrival Month:**
#
# There are variations in booking patterns between resort and city hotels across different months, suggesting the need for targeted marketing campaigns.
#
# **Sum of People by Hotel Type:**
#
# Understanding the number of people per reservation for each hotel type is crucial for resource allocation and staffing.
#
# **Waiting List and Lead Time Analysis:**
#
# Analyzing waiting list and lead time data helps in refining booking policies for a better customer experience.
#
# **Top Countries with Maximum Stays:**
#
# Identifying top countries with extended stays allows for targeted international marketing efforts.
#
# **Cancellation Status:**
#
# A significant portion of bookings are canceled, indicating the importance of strategies to mitigate cancellations.
#
# **Correlation of Numerical Features:**
#
# Understanding the relationships between numerical features helps in refining pricing strategies and service offerings.
#
# **Pair Plot of Selected Numerical Features:**
#
# Identifying potential trends and relationships between numerical features for further analysis and improvement.
# In order to achieve the business objectives, it is recommended to implement targeted marketing strategies, refine booking policies, optimize pricing strategies, and tailor services based on customer preferences. Regular monitoring and adjustment of these strategies will be essential for continued success. Additionally, gathering customer feedback and conducting further market research can provide additional insights for refinement and improvement.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
